# %% [markdown]
# <a href="https://colab.research.google.com/github/JaroslavHolecek/Teaching_Solutions/blob/main/MatPlotLib/uvod_reseni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MatPlotLib
# MatPlotLib je Python knihovna určená pro zobrazování grafů. Její použití je velmi jednoduché a intuitivní. V této kapitole si ukážeme základní použití MatPlotLibu.
# Jako první musíme knihovnu nainstalovat.

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\podrazky\appdata\local\programs\python\python312\lib\site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\podrazky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\podrazky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\podrazky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\podrazky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\podrazky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\podrazky\appdata\roaming\python\python312\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\podrazky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\podrazky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\podrazky\appdata\roaming\python\python312\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\podrazky\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# Pro první použití této knihovny si ji musíme přidat do kódu pomocí importu. Přidáme si k tomu i knihovnu Numpy, pomocí této knihovny budeme upravovat data k zobrazení.

# %%
import matplotlib.pyplot as plt
import numpy as np

# pomocí funkce array si vytvoříme pole pomocí knihovny numpy
x_body = np.array([0, 6])
y_body = np.array([0, 250])

# funkcí plot vytvoříme samotný graf a naneseme na něj body
plt.plot(x_body, y_body)
# nakonec použijeme show pro zobrazení
plt.show()

# %% [markdown]
# V základu jsou body spojeny čárami, pokud ale chceme zobrazit pouze body bez čar, tak použijeme parametr marker="o".

# %%
# funkcí plot vytvoříme samotný graf a naneseme na něj body
plt.plot(x_body, y_body, "o")
# nakonec použijeme show pro zobrazení
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 # funkcí plot vytvoříme samotný graf a naneseme na něj body
# ----> 2 plt.plot(x_body, y_body, "O")
#       3 # nakonec použijeme show pro zobrazení
#       4 plt.show()
#
# File c:\Users\podrazky\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File c:\Users\podrazky\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File c:\Users\podrazky\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\podrazky\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:449, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     446 if len(tup) > 1 and isinstance(tup[-1], str):
#     447     # xy is tup with fmt stripped (could still be (y,) only)
#     448     *xy, fmt = tup
# --> 449     linestyle, marker, color = _process_plot_format(
#     450         fmt, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     451 elif len(tup) == 3:
#     452     raise ValueError('third arg must be a format string')
#
# File c:\Users\podrazky\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:197, in _process_plot_format(fmt, ambiguous_fmt_datakey)
#     195         i += 2
#     196     else:
# --> 197         raise ValueError(
#     198             errfmt.format(fmt, f"unrecognized character {c!r}"))
#     200 if linestyle is None and marker is None:
#     201     linestyle = mpl.rcParams['lines.linestyle']
#
# ValueError: 'O' is not a valid format string (unrecognized character 'O')

# %% [markdown]
# Můžeme zobrazit takový počet čísel kolik potřebujeme, musíme se ale ujistit, že počet prvků na obou osách je stejný

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Pokud použijeme pole rozdílných velikostí program nám vyhodí chybu.

# %%
xpoints = np.array([1, 2, 6, 8, 12])
ypoints = np.array([3, 8, 1, 10])

try:
    plt.plot(xpoints, ypoints)
    plt.show()
except Exception as e:
    print(e)
# Out:
# x and y must have same first dimension, but have shapes (5,) and (4,)

# %% [markdown]
# Ne vždy musíme do fuknce plot dávat 2 pole hodnot, pokud chceme aby osa x byla číslovaná od 0 s krokem po 1, stačí když použijeme pouze pole v hodnotami na ose y

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)
plt.show()

# %% [markdown]
# # Cvičení
# Zde bude následovat série úkolů, díky kterým si můžete ověřit, zda jste látku pochopili.
#
# ## Cvičení 1
# Vytvořte graf, který bude mít na ose x hodnoty 1,2,3,4,5 a na ose y hodnoty 1,4,9,16,25

# %%
# TODO: zde vytvořte graf

# ===== Začátek řešení =========

# ===== Konec řešení ==========

# %% [markdown]
# **Očekávaný výstup:**
#
# ![Output](./imgs/uvod_1.png)

# %% [markdown]
# ## Cvičení 2
# Vytvořte graf, který bude mít na ose x hodnoty 1,2,3,4,5 a na ose y hodnoty 1,8,27,64,125. Použijte pouze jedno pole hodnot.

# %%
# TODO: zde vytvořte graf

# ===== Začátek řešení =========
# ===== Konec řešení ==========

# %% [markdown]
# **Očekávaný výstup:**
#
# ![Output](./imgs/uvod_2.png)

# %% [markdown]
# ## Cvičení 3
# Vytvořte graf s 2 čárami, které budou mít na ose x hodnoty 1,2,3,4,5 a na ose y náhodné hodnoty od 0 do 100, náhodné hodnoty vygenerujte pomocí knihovny random.

# %%
# TODO: zde vytvořte graf

# ===== Začátek řešení =========

# ===== Konec řešení ==========

# %% [markdown]
# **Očekávaný výstup**
#
# ![Output](./imgs/uvod_3.png)
